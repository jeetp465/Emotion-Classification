# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import datasets, transforms, models
from torch.autograd import Variable
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from skimage import io
import os
from PIL import Image
import numpy as np

# %%
path = '/home/jeet/WEBEmo/category.txt'

with open(path, 'r') as f:
    content = f.readlines()
    
content = [elem.strip('\n').split(',') for elem in content]   

for elem in content:
    if elem[2] == '+':
        elem[2] = 'positive'
    else:
        elem[2] = 'negative'
        
print (content)
# Out:
# [['affection', 'love', 'positive'], ['cheerfullness', 'joy', 'positive'], ['confusion', 'confusion', 'negative'], ['contentment', 'joy', 'positive'], ['disappointment', 'sadness', 'negative'], ['disgust', 'anger', 'negative'], ['enthrallment', 'joy', 'positive'], ['envy', 'anger', 'negative'], ['exasperation', 'anger', 'negative'], ['gratitude', 'love', 'positive'], ['horror', 'fear', 'negative'], ['irritabilty', 'anger', 'negative'], ['lust', 'love', 'positive'], ['neglect', 'sadness', 'negative'], ['nervousness', 'fear', 'negative'], ['optimism', 'joy', 'positive'], ['pride', 'joy', 'positive'], ['rage', 'anger', 'negative'], ['relief', 'joy', 'positive'], ['sadness', 'sadness', 'negative'], ['shame', 'sadness', 'negative'], ['suffering', 'sadness', 'negative'], ['surprise', 'surprise', 'positive'], ['sympathy', 'sadness', 'negative'], ['zest', 'joy', 'positive']]

# %%
level1 = dict()
level2 = dict()

for i, elem in enumerate(content):
    
    if elem[2] not in level1.keys():
        level1[elem[2]] = []
    
    level1[elem[2]].append(i)
    
    if elem[1] not in level2.keys():
        level2[elem[1]] = []
        
    level2[elem[1]].append(i)
    
# print (level1)
# print (level2)

# %% [markdown]
# #### Custom Dataset Loader

# %%
# Function to extract the label of the folder 
def get_key(label_dict, val):
    for key, val_list in label_dict.items():
        if val in val_list:
            return key
        
# Function to make the dataset. Returns list of tuple (path, label) for the image
def make_dataset(root_dir, label_dict, class_to_idx):
    images = []
    for target in sorted(os.listdir(root_dir)):
        d = os.path.join(root_dir, target)
        
        try :
            int(target)
        except:
            continue
        
        label = get_key(label_dict, int(target))
        label = class_to_idx[label]

        for root, _, fnames in sorted(os.walk(d)):
            for fname in sorted(fnames):
                path = os.path.join(root, fname)
                item = (path, label)
                images.append(item)

    return images

# Helper function to load the images given the path of the image
def pil_loader(path):
    with open(path, 'rb') as f:
        img = Image.open(f)
        return img.convert('RGB')
    
# Attribute of the class Level1ImageDataSet    
def find_classes(root_dir, label_dict):
    classes = []
    
    for label_dir in sorted(os.listdir(root_dir)):
        try:
            int(label_dir)
            classes.append(get_key(label_dict, int(label_dir)))
        except:
            continue
    
    classes = list(set(classes))
    
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx

# %%
class Level1ImageDataset(Dataset):
    
    def __init__(self, root_dir, label_dict, transform=None):
        super(Level1ImageDataset, self).__init__()
        
        classes, class_to_idx = find_classes(root_dir, label_dict)
        samples = make_dataset(root_dir, label_dict, class_to_idx)
        
        self.root_dir = root_dir
        self.transform = transform
        self.label_dict = label_dict
        
        self.samples = samples
        self.classes = classes
        self.class_to_idx = class_to_idx
        
    def __len__(self):
        return (len(self.samples))
    
    def __getitem__(self, index):
        
        path, label = self.samples[index]
        sample = pil_loader(path)
        
        if self.transform is not None:
            sample = self.transform(sample)
        
        return sample, label
    
    def __repr__(self):
        fmt_str = 'Dataset ' + self.__class__.__name__ + '\n'
        fmt_str += '    Number of datapoints: {}\n'.format(self.__len__())
        fmt_str += '    Root Location: {}\n'.format(self.root_dir)
        tmp = '    Transforms (if any): '
        fmt_str += '{0}{1}\n'.format(tmp, self.transform.__repr__().replace('\n', '\n' + ' ' * len(tmp)))
        return fmt_str

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
data_dir = '/home/jeet/WEBEmo/'
BATCH_SIZE = 32

dset_l1 = {x: Level1ImageDataset(os.path.join(data_dir, x), level1, data_transforms[x])
         for x in ['train', 'test']}

dset_loaders = {x: torch.utils.data.DataLoader(dset_l1[x], batch_size=BATCH_SIZE, shuffle=True, num_workers=16)
                for x in ['train', 'test']}

dset_sizes = {x: len(dset_l1[x]) for x in ['train', 'test']}

dset_classes = dset_l1['train'].classes

# %%
def train(model, criterion, optimizer, num_epochs = 20):
    
    for epoch in range(num_epochs):
        model.train()
        
        best_acc = 0.0
        epoch_acc = 0.0
        epoch_loss = 0.0
        train_loss = 0.0
        train_acc = 0.0
        
        for i, (images, labels) in enumerate(dset_loaders['train']):
            
            images = Variable(images.cuda())
            labels = Variable(labels.cuda())
        
            optimizer.zero_grad()
            outputs = model(images)
            
            _, preds = torch.max(outputs, 1)
            
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * images.size(0)
            train_acc += torch.sum(preds == labels.data)
            
            if i % 100 == 0:
                try:
                    avg = train_acc.double() / (i * BATCH_SIZE)
                    print ("Average correctly classified images till {} batches: {}".format(i, avg))
                except:
                    continue
            
        epoch_loss = train_loss / dset_sizes['train']
        epoch_acc = train_acc.double() / dset_sizes['train']
        
        print ("Epoch: {}, Epoch_Accuracy: {:.2f}, Epoch_loss: {:.4f}".format(epoch, epoch_acc, epoch_loss))
        
        # Evaluate on the test set
        test_acc = test(model)

        # Save the model if the test acc is greater than our current best
#         if test_acc > best_acc:
#             best_model_wt = model.state_dict()
#             print("Chekcpoint updated")
#             best_acc = test_acc

        # Print the metrics
        print("Test Accuracy: {:.4f}".format(test_acc))
        
    #Save the best model weights
#     torch.save(best_model_wt, "Resnet34_Transfer_Learning.model")

# %%
def test(model):
    model.eval()
    test_acc = 0.0
    
    for i, (images, labels) in enumerate(dset_loaders['test']):

        images = Variable(images.cuda())
        labels = Variable(labels.cuda())

        # Predict classes using images from the test set
        outputs = model(images)
        _, prediction = torch.max(outputs.data, 1)
        
        test_acc += torch.sum(prediction == labels.data)

    # Compute the average acc and loss over all test images
    test_acc = test_acc.double() / dset_sizes['test']

    return test_acc

# %%
model_conv = models.resnet34(pretrained=True)

for params in model_conv.parameters():
    params.requires_grad=False
    
num_features = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_features, 2)

model_conv.cuda()

criterion = nn.CrossEntropyLoss()

optimizer_conv = optim.Adam(model_conv.parameters(), lr=0.001, weight_decay=0.0001)

# %%
train(model_conv, criterion, optimizer_conv, num_epochs=10)
# Out:
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.5700000000000001
# Average correctly classified images till 200 batches: 0.5867187500000001
# Average correctly classified images till 300 batches: 0.5970833333333334
# Average correctly classified images till 400 batches: 0.59875
# Average correctly classified images till 500 batches: 0.601
# Average correctly classified images till 600 batches: 0.6047395833333333
# Average correctly classified images till 700 batches: 0.6045982142857143
# Average correctly classified images till 800 batches: 0.6066796875
# Average correctly classified images till 900 batches: 0.6085069444444444
# Average correctly classified images till 1000 batches: 0.61021875
# Average correctly classified images till 1100 batches: 0.6107386363636363
# Average correctly classified images till 1200 batches: 0.6124739583333334
# Average correctly classified images till 1300 batches: 0.613798076923077
# Average correctly classified images till 1400 batches: 0.6136830357142857
# Average correctly classified images till 1500 batches: 0.6130208333333333
# Average correctly classified images till 1600 batches: 0.61400390625
# Average correctly classified images till 1700 batches: 0.6138970588235294
# Average correctly classified images till 1800 batches: 0.6140625
# Average correctly classified images till 1900 batches: 0.6148355263157894
# Average correctly classified images till 2000 batches: 0.6160156250000001
# Average correctly classified images till 2100 batches: 0.6167113095238095
# Average correctly classified images till 2200 batches: 0.6165482954545455
# Average correctly classified images till 2300 batches: 0.6159782608695652
# Average correctly classified images till 2400 batches: 0.6166927083333333
# Average correctly classified images till 2500 batches: 0.6168125
# Average correctly classified images till 2600 batches: 0.6170552884615385
# Average correctly classified images till 2700 batches: 0.6176273148148148
# Average correctly classified images till 2800 batches: 0.6179575892857143
# Average correctly classified images till 2900 batches: 0.6183297413793103
# Average correctly classified images till 3000 batches: 0.6190729166666666
# Average correctly classified images till 3100 batches: 0.6187600806451613
# Average correctly classified images till 3200 batches: 0.618515625
# Average correctly classified images till 3300 batches: 0.6186363636363637
# Average correctly classified images till 3400 batches: 0.6189430147058823
# Average correctly classified images till 3500 batches: 0.6194732142857143
# Average correctly classified images till 3600 batches: 0.6201041666666667
# Average correctly classified images till 3700 batches: 0.6202027027027027
# Average correctly classified images till 3800 batches: 0.6202138157894737
# Average correctly classified images till 3900 batches: 0.6201762820512821
# Average correctly classified images till 4000 batches: 0.620375
# Average correctly classified images till 4100 batches: 0.6204496951219513
# Average correctly classified images till 4200 batches: 0.6207738095238096
# Average correctly classified images till 4300 batches: 0.6209811046511629
# Average correctly classified images till 4400 batches: 0.6213494318181818
# Average correctly classified images till 4500 batches: 0.6212222222222222
# Average correctly classified images till 4600 batches: 0.6212092391304348
# Average correctly classified images till 4700 batches: 0.6209375
# Average correctly classified images till 4800 batches: 0.6211002604166667
# Average correctly classified images till 4900 batches: 0.6211352040816327
# Average correctly classified images till 5000 batches: 0.6211562500000001
# Average correctly classified images till 5100 batches: 0.6215257352941176
# Average correctly classified images till 5200 batches: 0.6217548076923077
# Average correctly classified images till 5300 batches: 0.6220459905660377
# Average correctly classified images till 5400 batches: 0.6222106481481481
# Average correctly classified images till 5500 batches: 0.6224772727272727
# Average correctly classified images till 5600 batches: 0.6227622767857143
# Average correctly classified images till 5700 batches: 0.6231688596491227
# Average correctly classified images till 5800 batches: 0.6234105603448276
# Average correctly classified images till 5900 batches: 0.6235275423728814
# Average correctly classified images till 6000 batches: 0.6234999999999999
# Average correctly classified images till 6100 batches: 0.6232735655737704
# Average correctly classified images till 6200 batches: 0.6233921370967742
# Average correctly classified images till 6300 batches: 0.6234672619047619
# Average correctly classified images till 6400 batches: 0.6236962890625
# Average correctly classified images till 6500 batches: 0.6234086538461538
# Average correctly classified images till 6600 batches: 0.6235227272727273
# Epoch: 0, Epoch_Accuracy: 0.62, Epoch_loss: 0.6527
# Test Accuracy: 0.6509
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.64625
# Average correctly classified images till 200 batches: 0.635
# Average correctly classified images till 300 batches: 0.6428125
# Average correctly classified images till 400 batches: 0.64109375
# Average correctly classified images till 500 batches: 0.6373125000000001
# Average correctly classified images till 600 batches: 0.6365104166666667
# Average correctly classified images till 700 batches: 0.6363392857142857
# Average correctly classified images till 800 batches: 0.63546875
# Average correctly classified images till 900 batches: 0.6351388888888889
# Average correctly classified images till 1000 batches: 0.63471875
# Average correctly classified images till 1100 batches: 0.6348011363636363
# Average correctly classified images till 1200 batches: 0.6343229166666667
# Average correctly classified images till 1300 batches: 0.6339182692307692
# Average correctly classified images till 1400 batches: 0.6346205357142857
# Average correctly classified images till 1500 batches: 0.6336666666666666
# Average correctly classified images till 1600 batches: 0.6335937500000001
# Average correctly classified images till 1700 batches: 0.6331249999999999
# Average correctly classified images till 1800 batches: 0.6317881944444445
# Average correctly classified images till 1900 batches: 0.6314144736842106
# Average correctly classified images till 2000 batches: 0.631140625
# Average correctly classified images till 2100 batches: 0.6306547619047619
# Average correctly classified images till 2200 batches: 0.6305255681818182
# Average correctly classified images till 2300 batches: 0.630625
# Average correctly classified images till 2400 batches: 0.6306770833333334
# Average correctly classified images till 2500 batches: 0.630575
# Average correctly classified images till 2600 batches: 0.6306850961538462
# Average correctly classified images till 2700 batches: 0.6307060185185185
# Average correctly classified images till 2800 batches: 0.6305357142857143
# Average correctly classified images till 2900 batches: 0.6310560344827586
# Average correctly classified images till 3000 batches: 0.6310104166666667
# Average correctly classified images till 3100 batches: 0.6309778225806452
# Average correctly classified images till 3200 batches: 0.6305078125
# Average correctly classified images till 3300 batches: 0.6305208333333333
# Average correctly classified images till 3400 batches: 0.630689338235294
# Average correctly classified images till 3500 batches: 0.6305982142857144
# Average correctly classified images till 3600 batches: 0.6304861111111111
# Average correctly classified images till 3700 batches: 0.630616554054054
# Average correctly classified images till 3800 batches: 0.6303453947368421
# Average correctly classified images till 3900 batches: 0.6306330128205129
# Average correctly classified images till 4000 batches: 0.6305625
# Average correctly classified images till 4100 batches: 0.6305868902439025
# Average correctly classified images till 4200 batches: 0.6300297619047619
# Average correctly classified images till 4300 batches: 0.6298619186046512
# Average correctly classified images till 4400 batches: 0.6297230113636364
# Average correctly classified images till 4500 batches: 0.6295416666666667
# Average correctly classified images till 4600 batches: 0.6295584239130435
# Average correctly classified images till 4700 batches: 0.6294547872340426
# Average correctly classified images till 4800 batches: 0.6293098958333334
# Average correctly classified images till 4900 batches: 0.6293813775510204
# Average correctly classified images till 5000 batches: 0.6294937500000001
# Average correctly classified images till 5100 batches: 0.6295526960784313
# Average correctly classified images till 5200 batches: 0.6294891826923077
# Average correctly classified images till 5300 batches: 0.629192216981132
# Average correctly classified images till 5400 batches: 0.6287789351851851
# Average correctly classified images till 5500 batches: 0.6290511363636363
# Average correctly classified images till 5600 batches: 0.6291183035714286
# Average correctly classified images till 5700 batches: 0.629172149122807
# Average correctly classified images till 5800 batches: 0.6291487068965517
# Average correctly classified images till 5900 batches: 0.6291260593220339
# Average correctly classified images till 6000 batches: 0.6290833333333333
# Average correctly classified images till 6100 batches: 0.6290881147540983
# Average correctly classified images till 6200 batches: 0.6290675403225806
# Average correctly classified images till 6300 batches: 0.6292311507936508
# Average correctly classified images till 6400 batches: 0.62904296875
# Average correctly classified images till 6500 batches: 0.628985576923077
# Average correctly classified images till 6600 batches: 0.6287784090909091
# Epoch: 1, Epoch_Accuracy: 0.63, Epoch_loss: 0.6479
# Test Accuracy: 0.6433
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.636875
# Average correctly classified images till 200 batches: 0.63484375
# Average correctly classified images till 300 batches: 0.6291666666666667
# Average correctly classified images till 400 batches: 0.62953125
# Average correctly classified images till 500 batches: 0.6273125
# Average correctly classified images till 600 batches: 0.6301562500000001
# Average correctly classified images till 1300 batches: 0.6262980769230769
# Average correctly classified images till 1400 batches: 0.6274107142857143
# Average correctly classified images till 1500 batches: 0.62775
# Average correctly classified images till 1600 batches: 0.6276953125
# Average correctly classified images till 1700 batches: 0.6280698529411765
# Average correctly classified images till 1800 batches: 0.6266666666666667
# Average correctly classified images till 1900 batches: 0.6260855263157895
# Average correctly classified images till 2000 batches: 0.62646875
# Average correctly classified images till 2100 batches: 0.6273511904761905
# Average correctly classified images till 2200 batches: 0.6272869318181818
# Average correctly classified images till 2300 batches: 0.6278532608695653
# Average correctly classified images till 2400 batches: 0.6277604166666667
# Average correctly classified images till 2500 batches: 0.6275875000000001
# Average correctly classified images till 2600 batches: 0.6281610576923077
# Average correctly classified images till 2700 batches: 0.6277662037037036
# Average correctly classified images till 2800 batches: 0.6281696428571428
# Average correctly classified images till 2900 batches: 0.6276293103448275
# Average correctly classified images till 3000 batches: 0.6282916666666667
# Average correctly classified images till 3100 batches: 0.6288608870967742
# Average correctly classified images till 3200 batches: 0.628642578125
# Average correctly classified images till 3300 batches: 0.6285511363636364
# Average correctly classified images till 3400 batches: 0.6284834558823529
# Average correctly classified images till 3500 batches: 0.628375
# Average correctly classified images till 3600 batches: 0.6282552083333334
# Average correctly classified images till 3700 batches: 0.6284543918918919
# Average correctly classified images till 3800 batches: 0.628626644736842
# Average correctly classified images till 3900 batches: 0.6286778846153847
# Average correctly classified images till 4000 batches: 0.6284453125
# Average correctly classified images till 4100 batches: 0.6287118902439024
# Average correctly classified images till 4200 batches: 0.6286309523809523
# Average correctly classified images till 4300 batches: 0.6284084302325582
# Average correctly classified images till 4400 batches: 0.6285298295454546
# Average correctly classified images till 4500 batches: 0.6287013888888889
# Average correctly classified images till 4600 batches: 0.6287092391304349
# Average correctly classified images till 4700 batches: 0.6286170212765957
# Average correctly classified images till 4800 batches: 0.6282291666666667
# Average correctly classified images till 4900 batches: 0.6282334183673469
# Average correctly classified images till 5000 batches: 0.62819375
# Average correctly classified images till 5100 batches: 0.6283517156862745
# Average correctly classified images till 5200 batches: 0.6285757211538462
# Average correctly classified images till 5300 batches: 0.628130896226415
# Average correctly classified images till 5400 batches: 0.6282696759259259
# Average correctly classified images till 5500 batches: 0.6286363636363635
# Average correctly classified images till 5600 batches: 0.6286439732142857
# Average correctly classified images till 5700 batches: 0.6284978070175438
# Average correctly classified images till 5800 batches: 0.6286045258620689
# Average correctly classified images till 5900 batches: 0.6284639830508475
# Average correctly classified images till 6000 batches: 0.6284375
# Average correctly classified images till 6100 batches: 0.6283504098360656
# Average correctly classified images till 6200 batches: 0.6283770161290323
# Average correctly classified images till 6300 batches: 0.6283184523809524
# Average correctly classified images till 6400 batches: 0.62849609375
# Average correctly classified images till 6500 batches: 0.6285576923076923
# Average correctly classified images till 6600 batches: 0.6284801136363637
# Epoch: 2, Epoch_Accuracy: 0.63, Epoch_loss: 0.6484
# Test Accuracy: 0.6236
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.64125
# Average correctly classified images till 200 batches: 0.6278125
# Average correctly classified images till 300 batches: 0.6269791666666668
# Average correctly classified images till 400 batches: 0.628359375
# Average correctly classified images till 500 batches: 0.6255000000000001
# Average correctly classified images till 600 batches: 0.6256770833333334
# Average correctly classified images till 700 batches: 0.6279017857142857
# Average correctly classified images till 800 batches: 0.6284375
# Average correctly classified images till 900 batches: 0.6288888888888889
# Average correctly classified images till 1000 batches: 0.62953125
# Average correctly classified images till 1100 batches: 0.6290909090909091
# Average correctly classified images till 1200 batches: 0.629765625
# Average correctly classified images till 1300 batches: 0.6294471153846154
# Average correctly classified images till 1400 batches: 0.6298660714285714
# Average correctly classified images till 1500 batches: 0.6283124999999999
# Average correctly classified images till 1600 batches: 0.6278125
# Average correctly classified images till 1700 batches: 0.6282904411764705
# Average correctly classified images till 1800 batches: 0.6269444444444444
# Average correctly classified images till 1900 batches: 0.6269243421052632
# Average correctly classified images till 2000 batches: 0.627140625
# Average correctly classified images till 2100 batches: 0.6271130952380952
# Average correctly classified images till 2200 batches: 0.62734375
# Average correctly classified images till 2300 batches: 0.6263994565217391
# Average correctly classified images till 2400 batches: 0.6263932291666667
# Average correctly classified images till 2500 batches: 0.626275
# Average correctly classified images till 2600 batches: 0.6257572115384615
# Average correctly classified images till 2700 batches: 0.626087962962963
# Average correctly classified images till 2800 batches: 0.6260267857142857
# Average correctly classified images till 2900 batches: 0.6264008620689655
# Average correctly classified images till 3000 batches: 0.626625
# Average correctly classified images till 3100 batches: 0.6265524193548387
# Average correctly classified images till 3200 batches: 0.62658203125
# Average correctly classified images till 3300 batches: 0.6266761363636364
# Average correctly classified images till 3400 batches: 0.6270404411764705
# Average correctly classified images till 3500 batches: 0.6266517857142858
# Average correctly classified images till 3600 batches: 0.6270920138888889
# Average correctly classified images till 3700 batches: 0.6275337837837838
# Average correctly classified images till 3800 batches: 0.627483552631579
# Average correctly classified images till 3900 batches: 0.6277323717948718
# Average correctly classified images till 4000 batches: 0.6278359375
# Average correctly classified images till 4100 batches: 0.6280335365853659
# Average correctly classified images till 4200 batches: 0.6280877976190476
# Average correctly classified images till 4300 batches: 0.6283502906976745
# Average correctly classified images till 4400 batches: 0.6286221590909091
# Average correctly classified images till 4500 batches: 0.6290486111111111
# Average correctly classified images till 4600 batches: 0.6289470108695653
# Average correctly classified images till 4700 batches: 0.629095744680851
# Average correctly classified images till 4800 batches: 0.6292122395833334
# Average correctly classified images till 4900 batches: 0.6295344387755102
# Average correctly classified images till 5000 batches: 0.62936875
# Average correctly classified images till 5100 batches: 0.629454656862745
# Average correctly classified images till 5200 batches: 0.6295012019230769
# Average correctly classified images till 5300 batches: 0.6293867924528301
# Average correctly classified images till 5400 batches: 0.6294675925925926
# Average correctly classified images till 5500 batches: 0.6294318181818181
# Average correctly classified images till 5600 batches: 0.6295256696428572
# Average correctly classified images till 5700 batches: 0.6296107456140351
# Average correctly classified images till 5800 batches: 0.629364224137931
# Average correctly classified images till 5900 batches: 0.6295550847457627
# Average correctly classified images till 6000 batches: 0.62953125
# Average correctly classified images till 6100 batches: 0.6292418032786885
# Average correctly classified images till 6200 batches: 0.6291885080645161
# Average correctly classified images till 6300 batches: 0.629077380952381
# Average correctly classified images till 6400 batches: 0.62921875
# Average correctly classified images till 6500 batches: 0.6292115384615384
# Average correctly classified images till 6600 batches: 0.6291098484848485
# Epoch: 3, Epoch_Accuracy: 0.63, Epoch_loss: 0.6486
# Test Accuracy: 0.6508
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.635
# Average correctly classified images till 200 batches: 0.63375
# Average correctly classified images till 300 batches: 0.6335416666666667
# Average correctly classified images till 400 batches: 0.635
# Average correctly classified images till 500 batches: 0.6363125000000001
# Average correctly classified images till 600 batches: 0.63703125
# Average correctly classified images till 700 batches: 0.6349107142857143
# Average correctly classified images till 800 batches: 0.6332421875
# Average correctly classified images till 900 batches: 0.6332638888888888
# Average correctly classified images till 1000 batches: 0.632875
# Average correctly classified images till 1100 batches: 0.6319886363636363
# Average correctly classified images till 1200 batches: 0.6325260416666667
# Average correctly classified images till 1300 batches: 0.6314663461538461
# Average correctly classified images till 1400 batches: 0.63046875
# Average correctly classified images till 1500 batches: 0.6305208333333333
# Average correctly classified images till 1600 batches: 0.6308984375
# Average correctly classified images till 1700 batches: 0.6319669117647059
# Average correctly classified images till 1800 batches: 0.6316493055555555
# Average correctly classified images till 1900 batches: 0.6309868421052631
# Average correctly classified images till 2000 batches: 0.630984375
# Average correctly classified images till 2100 batches: 0.6315773809523809
# Average correctly classified images till 2200 batches: 0.631278409090909
# Average correctly classified images till 2300 batches: 0.6315353260869565
# Average correctly classified images till 2400 batches: 0.6314192708333334
# Average correctly classified images till 2500 batches: 0.63125
# Average correctly classified images till 2600 batches: 0.6313942307692307
# Average correctly classified images till 2700 batches: 0.6316319444444444
# Average correctly classified images till 2800 batches: 0.6314620535714286
# Average correctly classified images till 2900 batches: 0.6309482758620689
# Average correctly classified images till 3000 batches: 0.63071875
# Average correctly classified images till 3100 batches: 0.6305544354838709
# Average correctly classified images till 3200 batches: 0.630107421875
# Average correctly classified images till 3300 batches: 0.6298295454545455
# Average correctly classified images till 3400 batches: 0.6302022058823529
# Average correctly classified images till 3500 batches: 0.6300446428571429
# Average correctly classified images till 3600 batches: 0.6304079861111112
# Average correctly classified images till 3700 batches: 0.630954391891892
# Average correctly classified images till 3800 batches: 0.631389802631579
# Average correctly classified images till 3900 batches: 0.63125
# Average correctly classified images till 4000 batches: 0.630890625
# Average correctly classified images till 4100 batches: 0.6308841463414634
# Average correctly classified images till 4200 batches: 0.6307142857142857
# Average correctly classified images till 4300 batches: 0.6309883720930233
# Average correctly classified images till 4400 batches: 0.6309588068181818
# Average correctly classified images till 4500 batches: 0.6306805555555556
# Average correctly classified images till 4600 batches: 0.6304279891304349
# Average correctly classified images till 4700 batches: 0.6302260638297872
# Average correctly classified images till 4800 batches: 0.6302473958333333
# Average correctly classified images till 4900 batches: 0.6301785714285715
# Average correctly classified images till 5000 batches: 0.62995
# Average correctly classified images till 5100 batches: 0.6297242647058823
# Average correctly classified images till 5200 batches: 0.6294651442307693
# Average correctly classified images till 5300 batches: 0.6291863207547169
# Average correctly classified images till 5400 batches: 0.6292303240740741
# Average correctly classified images till 5500 batches: 0.6290454545454545
# Average correctly classified images till 5600 batches: 0.6290011160714286
# Average correctly classified images till 5700 batches: 0.6289802631578947
# Average correctly classified images till 5800 batches: 0.6289870689655171
# Average correctly classified images till 5900 batches: 0.629406779661017
# Average correctly classified images till 6000 batches: 0.6293697916666666
# Average correctly classified images till 6100 batches: 0.6293647540983607
# Average correctly classified images till 6200 batches: 0.6295715725806451
# Average correctly classified images till 6300 batches: 0.6295585317460317
# Average correctly classified images till 6400 batches: 0.6294384765625
# Average correctly classified images till 6500 batches: 0.6293125
# Average correctly classified images till 6600 batches: 0.6293134469696969
# Epoch: 4, Epoch_Accuracy: 0.63, Epoch_loss: 0.6472
# Test Accuracy: 0.6475
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.6371875
# Average correctly classified images till 200 batches: 0.63390625
# Average correctly classified images till 300 batches: 0.6361458333333334
# Average correctly classified images till 400 batches: 0.635390625
# Average correctly classified images till 500 batches: 0.635375
# Average correctly classified images till 600 batches: 0.6324479166666667
# Average correctly classified images till 700 batches: 0.6341071428571429
# Average correctly classified images till 800 batches: 0.6341796875
# Average correctly classified images till 900 batches: 0.6314583333333333
# Average correctly classified images till 1000 batches: 0.630375
# Average correctly classified images till 1100 batches: 0.6298295454545455
# Average correctly classified images till 1200 batches: 0.629140625
# Average correctly classified images till 1300 batches: 0.6284615384615385
# Average correctly classified images till 1400 batches: 0.6284151785714286
# Average correctly classified images till 1500 batches: 0.6287291666666667
# Average correctly classified images till 1600 batches: 0.6290625
# Average correctly classified images till 1700 batches: 0.6285845588235294
# Average correctly classified images till 1800 batches: 0.6288715277777778
# Average correctly classified images till 1900 batches: 0.6291940789473685
# Average correctly classified images till 2000 batches: 0.630296875
# Average correctly classified images till 2100 batches: 0.6301785714285715
# Average correctly classified images till 2200 batches: 0.6303977272727272
# Average correctly classified images till 2300 batches: 0.6304891304347826
# Average correctly classified images till 2400 batches: 0.6299479166666667
# Average correctly classified images till 2500 batches: 0.6297375000000001
# Average correctly classified images till 2600 batches: 0.6291466346153847
# Average correctly classified images till 2700 batches: 0.6286689814814814
# Average correctly classified images till 2800 batches: 0.6283482142857143
# Average correctly classified images till 2900 batches: 0.6279633620689654
# Average correctly classified images till 3000 batches: 0.6274479166666667
# Average correctly classified images till 3100 batches: 0.626945564516129
# Average correctly classified images till 3200 batches: 0.6272265625
# Average correctly classified images till 3300 batches: 0.6275378787878788
# Average correctly classified images till 3400 batches: 0.6281525735294117
# Average correctly classified images till 3500 batches: 0.6285714285714287
# Average correctly classified images till 3600 batches: 0.6282118055555556
# Average correctly classified images till 3700 batches: 0.6284121621621622
# Average correctly classified images till 3800 batches: 0.62828125
# Average correctly classified images till 3900 batches: 0.6284134615384616
# Average correctly classified images till 4000 batches: 0.6280859375
# Average correctly classified images till 4100 batches: 0.6281021341463414
# Average correctly classified images till 4200 batches: 0.6282068452380952
# Average correctly classified images till 4300 batches: 0.6282049418604652
# Average correctly classified images till 4400 batches: 0.62796875
# Average correctly classified images till 4500 batches: 0.6278055555555556
# Average correctly classified images till 4600 batches: 0.6279347826086957
# Average correctly classified images till 4700 batches: 0.6280984042553192
# Average correctly classified images till 4800 batches: 0.6280924479166667
# Average correctly classified images till 4900 batches: 0.6281696428571428
# Average correctly classified images till 5000 batches: 0.6282875
# Average correctly classified images till 5100 batches: 0.6281372549019607
# Average correctly classified images till 5200 batches: 0.6282512019230769
# Average correctly classified images till 5300 batches: 0.6286320754716981
# Average correctly classified images till 5400 batches: 0.6288888888888888
# Average correctly classified images till 5500 batches: 0.6289318181818181
# Average correctly classified images till 5600 batches: 0.6288113839285714
# Average correctly classified images till 5700 batches: 0.629172149122807
# Average correctly classified images till 5800 batches: 0.6294181034482759
# Average correctly classified images till 5900 batches: 0.6292690677966102
# Average correctly classified images till 6000 batches: 0.6294166666666666
# Average correctly classified images till 6100 batches: 0.6296977459016393
# Average correctly classified images till 6200 batches: 0.6295010080645161
# Average correctly classified images till 6300 batches: 0.6293849206349207
# Average correctly classified images till 6400 batches: 0.6296240234375
# Average correctly classified images till 6500 batches: 0.6296153846153847
# Average correctly classified images till 6600 batches: 0.6298532196969697
# Epoch: 5, Epoch_Accuracy: 0.63, Epoch_loss: 0.6482
# Test Accuracy: 0.6528
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.64625
# Average correctly classified images till 200 batches: 0.6325000000000001
# Average correctly classified images till 300 batches: 0.6329166666666667
# Average correctly classified images till 400 batches: 0.633671875
# Average correctly classified images till 500 batches: 0.633
# Average correctly classified images till 600 batches: 0.6319791666666668
# Average correctly classified images till 700 batches: 0.6323660714285714
# Average correctly classified images till 800 batches: 0.631875
# Average correctly classified images till 900 batches: 0.6328125
# Average correctly classified images till 1000 batches: 0.632375
# Average correctly classified images till 1100 batches: 0.6327272727272727
# Average correctly classified images till 1200 batches: 0.6322395833333334
# Average correctly classified images till 1300 batches: 0.6315865384615384
# Average correctly classified images till 1400 batches: 0.6320089285714285
# Average correctly classified images till 1500 batches: 0.6318125
# Average correctly classified images till 1600 batches: 0.63099609375
# Average correctly classified images till 1700 batches: 0.631672794117647
# Average correctly classified images till 1800 batches: 0.6313888888888889
# Average correctly classified images till 1900 batches: 0.6326151315789473
# Average correctly classified images till 2000 batches: 0.633109375
# Average correctly classified images till 2100 batches: 0.632514880952381
# Average correctly classified images till 2200 batches: 0.6323153409090909
# Average correctly classified images till 2300 batches: 0.6321467391304348
# Average correctly classified images till 2400 batches: 0.6323177083333333
# Average correctly classified images till 2500 batches: 0.6319125
# Average correctly classified images till 2600 batches: 0.6315504807692308
# Average correctly classified images till 2700 batches: 0.6321180555555556
# Average correctly classified images till 2800 batches: 0.6321540178571429
# Average correctly classified images till 2900 batches: 0.6323275862068966
# Average correctly classified images till 3000 batches: 0.6320104166666667
# Average correctly classified images till 3100 batches: 0.6319254032258065
# Average correctly classified images till 3200 batches: 0.632041015625
# Average correctly classified images till 3300 batches: 0.6319886363636363
# Average correctly classified images till 3400 batches: 0.6319944852941176
# Average correctly classified images till 3500 batches: 0.6320625000000001
# Average correctly classified images till 3600 batches: 0.6316232638888889
# Average correctly classified images till 3700 batches: 0.6312922297297298
# Average correctly classified images till 3800 batches: 0.6313733552631579
# Average correctly classified images till 3900 batches: 0.6311057692307692
# Average correctly classified images till 4000 batches: 0.6310703125
# Average correctly classified images till 4100 batches: 0.6304344512195122
# Average correctly classified images till 4200 batches: 0.6302306547619048
# Average correctly classified images till 4300 batches: 0.6301816860465117
# Average correctly classified images till 4400 batches: 0.630078125
# Average correctly classified images till 4500 batches: 0.6299930555555556
# Average correctly classified images till 4600 batches: 0.629476902173913
# Average correctly classified images till 4700 batches: 0.6291622340425532
# Average correctly classified images till 4800 batches: 0.6289453125000001
# Average correctly classified images till 4900 batches: 0.6289732142857143
# Average correctly classified images till 5000 batches: 0.62881875
# Average correctly classified images till 5100 batches: 0.6287745098039216
# Average correctly classified images till 5200 batches: 0.6289362980769231
# Average correctly classified images till 5300 batches: 0.6290860849056603
# Average correctly classified images till 5400 batches: 0.6292650462962963
# Average correctly classified images till 5500 batches: 0.6291818181818182
# Average correctly classified images till 5600 batches: 0.6290178571428572
# Average correctly classified images till 5700 batches: 0.628766447368421
# Average correctly classified images till 5800 batches: 0.6287661637931033
# Average correctly classified images till 5900 batches: 0.6289247881355933
# Average correctly classified images till 6000 batches: 0.6288072916666666
# Average correctly classified images till 6100 batches: 0.6286680327868852
# Average correctly classified images till 6200 batches: 0.6287247983870968
# Average correctly classified images till 6300 batches: 0.6287896825396826
# Average correctly classified images till 6400 batches: 0.6288330078125001
# Average correctly classified images till 6500 batches: 0.6288317307692308
# Average correctly classified images till 6600 batches: 0.6288352272727272
# Epoch: 6, Epoch_Accuracy: 0.63, Epoch_loss: 0.6494
# Test Accuracy: 0.6522
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.633125
# Average correctly classified images till 200 batches: 0.62046875
# Average correctly classified images till 300 batches: 0.6277083333333334
# Average correctly classified images till 400 batches: 0.629375
# Average correctly classified images till 500 batches: 0.62925
# Average correctly classified images till 600 batches: 0.6283333333333334
# Average correctly classified images till 700 batches: 0.6288839285714286
# Average correctly classified images till 800 batches: 0.629140625
# Average correctly classified images till 900 batches: 0.6283680555555555
# Average correctly classified images till 1000 batches: 0.6279375
# Average correctly classified images till 1100 batches: 0.6275
# Average correctly classified images till 1200 batches: 0.628671875
# Average correctly classified images till 1300 batches: 0.6284375
# Average correctly classified images till 1400 batches: 0.6281696428571428
# Average correctly classified images till 1500 batches: 0.6277916666666666
# Average correctly classified images till 1600 batches: 0.62935546875
# Average correctly classified images till 1700 batches: 0.6294301470588235
# Average correctly classified images till 1800 batches: 0.6301041666666667
# Average correctly classified images till 1900 batches: 0.6309703947368421
# Average correctly classified images till 2000 batches: 0.6306406250000001
# Average correctly classified images till 2100 batches: 0.6306994047619048
# Average correctly classified images till 2200 batches: 0.6313920454545454
# Average correctly classified images till 2300 batches: 0.6309375
# Average correctly classified images till 2400 batches: 0.6306510416666667
# Average correctly classified images till 2500 batches: 0.6308125
# Average correctly classified images till 2600 batches: 0.630673076923077
# Average correctly classified images till 2700 batches: 0.6306481481481481
# Average correctly classified images till 2800 batches: 0.6306696428571429
# Average correctly classified images till 2900 batches: 0.6303987068965516
# Average correctly classified images till 3000 batches: 0.6300729166666666
# Average correctly classified images till 3100 batches: 0.6301814516129032
# Average correctly classified images till 3200 batches: 0.630234375
# Average correctly classified images till 3300 batches: 0.630094696969697
# Average correctly classified images till 3400 batches: 0.6296966911764705
# Average correctly classified images till 3500 batches: 0.6295357142857143
# Average correctly classified images till 3600 batches: 0.6291666666666667
# Average correctly classified images till 3700 batches: 0.6290793918918919
# Average correctly classified images till 3800 batches: 0.6292105263157894
# Average correctly classified images till 3900 batches: 0.629463141025641
# Average correctly classified images till 4000 batches: 0.6291953125
# Average correctly classified images till 4100 batches: 0.6291463414634146
# Average correctly classified images till 4200 batches: 0.6294791666666667
# Average correctly classified images till 4300 batches: 0.6293241279069768
# Average correctly classified images till 4400 batches: 0.6288991477272727
# Average correctly classified images till 4500 batches: 0.6283194444444444
# Average correctly classified images till 4600 batches: 0.6286820652173913
# Average correctly classified images till 4700 batches: 0.6285571808510638
# Average correctly classified images till 4800 batches: 0.62841796875
# Average correctly classified images till 4900 batches: 0.6283992346938776
# Average correctly classified images till 5000 batches: 0.6283125
# Average correctly classified images till 5100 batches: 0.627892156862745
# Average correctly classified images till 5200 batches: 0.6280769230769231
# Average correctly classified images till 5300 batches: 0.6279893867924528
# Average correctly classified images till 5400 batches: 0.6280902777777777
# Average correctly classified images till 5500 batches: 0.6283181818181818
# Average correctly classified images till 5600 batches: 0.6282087053571429
# Average correctly classified images till 5700 batches: 0.6277850877192982
# Average correctly classified images till 5800 batches: 0.6281627155172413
# Average correctly classified images till 5900 batches: 0.6282203389830509
# Average correctly classified images till 6000 batches: 0.6280989583333333
# Average correctly classified images till 6100 batches: 0.6281659836065574
# Average correctly classified images till 6200 batches: 0.6279737903225806
# Average correctly classified images till 6300 batches: 0.628110119047619
# Average correctly classified images till 6400 batches: 0.6281396484375
# Average correctly classified images till 6500 batches: 0.6283221153846154
# Average correctly classified images till 6600 batches: 0.6284422348484848
# Epoch: 7, Epoch_Accuracy: 0.63, Epoch_loss: 0.6498
# Test Accuracy: 0.6283
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.6090625000000001
# Average correctly classified images till 200 batches: 0.60890625
# Average correctly classified images till 300 batches: 0.619375
# Average correctly classified images till 400 batches: 0.62140625
# Average correctly classified images till 500 batches: 0.6255000000000001
# Average correctly classified images till 600 batches: 0.6261979166666667
# Average correctly classified images till 700 batches: 0.6269196428571429
# Average correctly classified images till 800 batches: 0.6268359375
# Average correctly classified images till 900 batches: 0.6251041666666667
# Average correctly classified images till 1000 batches: 0.6260625
# Average correctly classified images till 1100 batches: 0.6272443181818181
# Average correctly classified images till 1200 batches: 0.6281510416666667
# Average correctly classified images till 1300 batches: 0.6283653846153846
# Average correctly classified images till 1400 batches: 0.6290401785714286
# Average correctly classified images till 1500 batches: 0.6286041666666666
# Average correctly classified images till 1600 batches: 0.62837890625
# Average correctly classified images till 1700 batches: 0.6284558823529411
# Average correctly classified images till 1800 batches: 0.6289409722222222
# Average correctly classified images till 1900 batches: 0.6283881578947368
# Average correctly classified images till 2000 batches: 0.6286406250000001
# Average correctly classified images till 2100 batches: 0.6286904761904762
# Average correctly classified images till 2200 batches: 0.6288494318181819
# Average correctly classified images till 2300 batches: 0.6287364130434783
# Average correctly classified images till 2400 batches: 0.6283723958333334
# Average correctly classified images till 2500 batches: 0.6284125
# Average correctly classified images till 2600 batches: 0.6287860576923077
# Average correctly classified images till 2700 batches: 0.628287037037037
# Average correctly classified images till 2800 batches: 0.6284933035714285
# Average correctly classified images till 2900 batches: 0.6285883620689655
# Average correctly classified images till 3000 batches: 0.6283645833333333
# Average correctly classified images till 3100 batches: 0.6285080645161291
# Average correctly classified images till 3200 batches: 0.62845703125
# Average correctly classified images till 3300 batches: 0.6287784090909091
# Average correctly classified images till 3400 batches: 0.6293841911764705
# Average correctly classified images till 3500 batches: 0.6292767857142858
# Average correctly classified images till 3600 batches: 0.6295052083333333
# Average correctly classified images till 3700 batches: 0.6297635135135136
# Average correctly classified images till 3800 batches: 0.630016447368421
# Average correctly classified images till 3900 batches: 0.6298717948717949
# Average correctly classified images till 4000 batches: 0.62996875
# Average correctly classified images till 4100 batches: 0.6298704268292683
# Average correctly classified images till 4200 batches: 0.6300223214285714
# Average correctly classified images till 4300 batches: 0.6300363372093024
# Average correctly classified images till 4400 batches: 0.6297727272727273
# Average correctly classified images till 4500 batches: 0.6298263888888889
# Average correctly classified images till 4600 batches: 0.6297622282608696
# Average correctly classified images till 4700 batches: 0.6300598404255319
# Average correctly classified images till 4800 batches: 0.6304101562500001
# Average correctly classified images till 4900 batches: 0.6301339285714286
# Average correctly classified images till 5000 batches: 0.6300125
# Average correctly classified images till 5100 batches: 0.6303860294117647
# Average correctly classified images till 5200 batches: 0.6307932692307693
# Average correctly classified images till 5300 batches: 0.6303891509433962
# Average correctly classified images till 5400 batches: 0.629994212962963
# Average correctly classified images till 5500 batches: 0.630153409090909
# Average correctly classified images till 5600 batches: 0.6300725446428571
# Average correctly classified images till 5700 batches: 0.6304660087719298
# Average correctly classified images till 5800 batches: 0.6303663793103448
# Average correctly classified images till 5900 batches: 0.6303866525423729
# Average correctly classified images till 6000 batches: 0.630390625
# Average correctly classified images till 6100 batches: 0.6300051229508197
# Average correctly classified images till 6200 batches: 0.6298891129032258
# Average correctly classified images till 6300 batches: 0.6299751984126984
# Average correctly classified images till 6400 batches: 0.6297314453125
# Average correctly classified images till 6500 batches: 0.6295336538461539
# Average correctly classified images till 6600 batches: 0.6295359848484848
# Epoch: 8, Epoch_Accuracy: 0.63, Epoch_loss: 0.6485
# Test Accuracy: 0.6512
# Average correctly classified images till 0 batches: inf
# Average correctly classified images till 100 batches: 0.6425
# Average correctly classified images till 200 batches: 0.63625
# Average correctly classified images till 300 batches: 0.6383333333333334
# Average correctly classified images till 400 batches: 0.63203125
# Average correctly classified images till 500 batches: 0.63225
# Average correctly classified images till 600 batches: 0.6315625
# Average correctly classified images till 700 batches: 0.6313392857142857
# Average correctly classified images till 800 batches: 0.6327734375
# Average correctly classified images till 900 batches: 0.6296527777777777
# Average correctly classified images till 1000 batches: 0.630875
# Average correctly classified images till 1100 batches: 0.6307386363636364
# Average correctly classified images till 1200 batches: 0.6301562500000001
# Average correctly classified images till 1300 batches: 0.6289423076923077
# Average correctly classified images till 1400 batches: 0.6285044642857143
# Average correctly classified images till 1500 batches: 0.6283541666666667
# Average correctly classified images till 1600 batches: 0.62751953125
# Average correctly classified images till 1700 batches: 0.6275551470588234
# Average correctly classified images till 1800 batches: 0.6275
# Average correctly classified images till 1900 batches: 0.6277960526315789
# Average correctly classified images till 2000 batches: 0.627703125
# Average correctly classified images till 2100 batches: 0.6281845238095238
# Average correctly classified images till 2200 batches: 0.628125
# Average correctly classified images till 2300 batches: 0.6276902173913044
# Average correctly classified images till 2400 batches: 0.6272135416666667
# Average correctly classified images till 2500 batches: 0.627075
# Average correctly classified images till 2600 batches: 0.6269711538461539
# Average correctly classified images till 2700 batches: 0.6266435185185185
# Average correctly classified images till 2800 batches: 0.6259375
# Average correctly classified images till 2900 batches: 0.6257004310344827
# Average correctly classified images till 3000 batches: 0.62653125
# Average correctly classified images till 3100 batches: 0.626633064516129
# Average correctly classified images till 3200 batches: 0.626650390625
# Average correctly classified images till 3300 batches: 0.6266950757575758
# Average correctly classified images till 3400 batches: 0.6261580882352941
# Average correctly classified images till 3500 batches: 0.6258392857142857
# Average correctly classified images till 3600 batches: 0.6258420138888889
# Average correctly classified images till 3700 batches: 0.6261233108108109
# Average correctly classified images till 3800 batches: 0.6262582236842105
# Average correctly classified images till 3900 batches: 0.6264102564102564
# Average correctly classified images till 4000 batches: 0.6261640625
# Average correctly classified images till 4100 batches: 0.6263262195121951
# Average correctly classified images till 4200 batches: 0.6267113095238095
# Average correctly classified images till 4300 batches: 0.6267732558139535
# Average correctly classified images till 4400 batches: 0.6269460227272727
# Average correctly classified images till 4500 batches: 0.6270902777777778
# Average correctly classified images till 4600 batches: 0.6271059782608696
# Average correctly classified images till 4700 batches: 0.6274135638297872
# Average correctly classified images till 4800 batches: 0.6276236979166667
# Average correctly classified images till 4900 batches: 0.6277551020408163
# Average correctly classified images till 5000 batches: 0.62815
# Average correctly classified images till 5100 batches: 0.628376225490196
# Average correctly classified images till 5200 batches: 0.6281490384615385
# Average correctly classified images till 5300 batches: 0.6279068396226415
# Average correctly classified images till 5400 batches: 0.6278009259259258
# Average correctly classified images till 5500 batches: 0.6277272727272727
# Average correctly classified images till 5600 batches: 0.6275669642857142
# Average correctly classified images till 5700 batches: 0.6278618421052631
# Average correctly classified images till 5800 batches: 0.6279364224137931
# Average correctly classified images till 5900 batches: 0.627844279661017
# Average correctly classified images till 6000 batches: 0.62765625
# Average correctly classified images till 6100 batches: 0.6272950819672131
# Average correctly classified images till 6200 batches: 0.6273639112903225
# Average correctly classified images till 6300 batches: 0.6273263888888889
# Average correctly classified images till 6400 batches: 0.62755859375
# Average correctly classified images till 6500 batches: 0.6274375
# Average correctly classified images till 6600 batches: 0.6273910984848485
# Epoch: 9, Epoch_Accuracy: 0.63, Epoch_loss: 0.6503
# Test Accuracy: 0.6552
